# %% [markdown]
# This is a UNET segmentation model, based on implementation in 'Segmentation Zoo'
#
# https://github.com/dbuscombe-usgs/segmentation_zoo
#
# Use Doodler to get labels for your images: https://github.com/dbuscombe-usgs/dash_doodler

# %%
# import the packages we need...
#first, the general stuff
import os
from os import getcwd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib


#import the tf stuff
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model

from tensorflow.keras.preprocessing.image import ImageDataGenerator

#Check TensorFlow Version
print('TF version: {}' .format(tf.__version__))
# Out:
# TF version: 2.8.0

# %%
#Check for GPU utilization
if tf.test.gpu_device_name():
    print(' GPU: {}'.format(tf.test.gpu_device_name()))
else:
    print("No GPU")
# Out:
#  GPU: /device:GPU:0

# %%
#define the number of classes of the image...these are NOAA, so 

num_classes = 3

#this is a fn to make sure the labels go from 0- (num_classes-1)

def D_Filter(image):
    image[image>(num_classes-1)] = (num_classes-1)
    return image

# %%
#build data flow routines, gettign the data from the files to the netowrk...

#first we decide how much of the data is training and how much is validation
split = 0.4

# Define dirs and files where the images and labels are.. Use doodler to get labels for your images!
image_dir = 'data/segmentation/images'
label_dir = 'data/segmentation/labels'

#to make it deterministic, set the seed
SEED = 201

# We will use generators to flow the data.. for both training and validaton
# We also add some weak data-augmentation, and rescale the images here.
# note that we are using the generator to split the data. 
train_image_datagen = ImageDataGenerator(rescale =1./255.,
                                   horizontal_flip = True,
                                   vertical_flip = True,
                                   validation_split = split)

train_mask_datagen = ImageDataGenerator(horizontal_flip = True,
                                   vertical_flip = True,
                                   preprocessing_function = D_Filter,
                                   validation_split = split )

#set batch Size for the model — how many images go into the network at each
#step. 
batch_size = 2

#set Image size. We are using a UNET based on Segmentation Zoo.. 
# size choices are:
#
#(RGB so imshape is 3)
pix_dim_x = 448
pix_dim_y = 448
imsize = (pix_dim_x,pix_dim_y) 
imshape = (pix_dim_x,pix_dim_y,3)

masksize = (pix_dim_x,pix_dim_y) 


### This is where we set the generator to flow images from the folders into the 
#training. The is a generator for the image and another for the mask. And also 
# generators for the traing and val.. so 4 total.:

train_image_generator = train_image_datagen.flow_from_directory(image_dir,
                                                    class_mode = None,
                                                    batch_size = batch_size,
                                                    target_size = imsize,
                                                    seed = SEED,
                                                    shuffle = False,
                                                    interpolation = "nearest",
                                                    subset ='training')

train_label_generator = train_mask_datagen.flow_from_directory(label_dir,
                                                    class_mode = None,
                                                    batch_size = batch_size,
                                                    target_size = masksize,
                                                    seed = SEED,
                                                    shuffle = False,
                                                    color_mode = "grayscale",
                                                    interpolation = "nearest",
                                                    subset = 'training')

# we merge the two training generators (image and mask) so that it looks like a
# a single generator 
train_generator = zip(train_image_generator, train_label_generator)



# Flow validation images in batches 


val_image_generator = train_image_datagen.flow_from_directory(image_dir, # same directory as training data
                                                    class_mode = None,
                                                    batch_size = batch_size,
                                                    target_size = imsize,
                                                    seed = SEED,
                                                    shuffle = False,
                                                    interpolation = "nearest",
                                                    subset = 'validation')

val_label_generator = train_mask_datagen.flow_from_directory(label_dir, # same directory as training data
                                                    class_mode = None,
                                                    batch_size = batch_size,
                                                    target_size = masksize,
                                                    seed = SEED,
                                                    shuffle = False,
                                                    color_mode = "grayscale",
                                                    interpolation = "nearest",
                                                    subset = 'validation')

#merge generators
validation_generator = zip(val_image_generator, val_label_generator)
# Out:
# Found 18 images belonging to 1 classes.
# Found 18 images belonging to 1 classes.
# Found 12 images belonging to 1 classes.
# Found 12 images belonging to 1 classes.

# %%
#Set total number of images in each subset, which is the output from the above cell.
# this will be used later when we train the model
total_train = 18
total_val = 12

# %%
#as an idiot check, lets look at the output of the generator.
#for a full training batch... 

x,y = next(train_generator)

for count,(im,lab) in enumerate(zip(x, y)):
    fig, (ax1, ax2) = plt.subplots(1, 2)
    ax1.imshow(im)
    ax2.matshow(lab.squeeze(), vmin = 0, vmax = 4)

# %%
#the model
#first we define the inputs, which is the shape of images defined in teh code blocks above 
inputs = layers.Input(imshape)

# 'Honey I shrunk the kids"'
# now we set up 4 blocks of comvolutons in the 'encoder' part
#block1
conv1 = layers.Conv2D(7, 2, activation = 'relu', strides=(1,1), padding="same")(inputs)
pool1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)

#block2
conv2 = layers.Conv2D(14, 2, activation = 'relu', strides=(1,1), padding="same")(pool1)
pool2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)

#block3
conv3 = layers.Conv2D(28, 3, activation = 'relu', strides=(1,1), padding="same")(pool2)
pool3 = layers.MaxPooling2D(pool_size=(2, 2))(conv3)

#block4
conv4 = layers.Conv2D(56, 3, activation = 'relu', strides=(1,1), padding="same")(pool3)
pool4 = layers.MaxPooling2D(pool_size=(2, 2))(conv4)


# we shrink as far as we are going to go...
#bottlneck
conv5 = layers.Conv2D(112, 2, activation = 'relu', strides=(1,1), padding="same")(pool4)

# # 'Honey I blew up the kids"... we upsample now
# #upblock 1
up6 = layers.Resizing(56, 56, interpolation='nearest')(conv5)
conc6 = layers.concatenate([up6, conv4])
conv6 = layers.Conv2D(56, 3, activation = 'relu', strides=(1,1), padding="same")(conc6)

#upblock 2
up7 = layers.Resizing(112, 112, interpolation='nearest')(conv6)
conc7 = layers.concatenate([up7, conv3])
conv7 = layers.Conv2D(28, 3, activation = 'relu', strides=(1,1), padding="same")(conc7)

#upblock 3
up8 = layers.Resizing(224, 224, interpolation='nearest')(conv7)
conc8 = layers.concatenate([up8, conv2])
conv8 = layers.Conv2D(14, 3, activation = 'relu', strides=(1,1), padding="same")(conc8)

#upblock 4
up9 = layers.Resizing(448, 448, interpolation='nearest')(conv8)
conc9 = layers.concatenate([up9, conv1])
conv9 = layers.Conv2D(7, 3, activation = 'relu', strides=(1,1), padding="same")(conc9)

#we define the outputs here
outputs = layers.Conv2D(num_classes, (1, 1), padding="same", activation="softmax")(conv9)


#combine the model together
model = Model(inputs, outputs)

#and print out the text summary of the model
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 448, 448, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 448, 448, 7)  91          ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 224, 224, 7)  0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 224, 224, 14  406         ['max_pooling2d[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 112, 112, 14  0          ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 112, 112, 28  3556        ['max_pooling2d_1[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 56, 56, 28)  0           ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 56, 56, 56)   14168       ['max_pooling2d_2[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 56)  0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 112)  25200       ['max_pooling2d_3[0][0]']
#
#  resizing (Resizing)            (None, 56, 56, 112)  0           ['conv2d_4[0][0]']
#
#  concatenate (Concatenate)      (None, 56, 56, 168)  0           ['resizing[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 56)   84728       ['concatenate[0][0]']
#
#  resizing_1 (Resizing)          (None, 112, 112, 56  0           ['conv2d_5[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 112, 112, 84  0           ['resizing_1[0][0]',
#                                 )                                 'conv2d_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 112, 112, 28  21196       ['concatenate_1[0][0]']
#                                 )
#
#  resizing_2 (Resizing)          (None, 224, 224, 28  0           ['conv2d_6[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 224, 224, 42  0           ['resizing_2[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 224, 224, 14  5306        ['concatenate_2[0][0]']
#                                 )
#
#  resizing_3 (Resizing)          (None, 448, 448, 14  0           ['conv2d_7[0][0]']
#                                 )
#
#  concatenate_3 (Concatenate)    (None, 448, 448, 21  0           ['resizing_3[0][0]',
#                                 )                                 'conv2d[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 448, 448, 7)  1330        ['concatenate_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 448, 448, 3)  24          ['conv2d_8[0][0]']
#
# ==================================================================================================
# Total params: 156,005
# Trainable params: 156,005
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# here is a graphic summary of the model... you can see the downsampling, bottleneck, and upsampling, connected to each other via skip connections
tf.keras.utils.plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
#we compile the model, set a loss function, and also an optimizer. 

model.compile( loss = tf.keras.losses.SparseCategoricalCrossentropy(),
              optimizer = tf.keras.optimizers.Adam(learning_rate = 0.0001),
             )

# %%
# define a callback, which runs during training and does something for us. 
#This one looks at the training loss, and stops the training if the loss does 
#not improve from some number of epochs. Then it reverts to the best version of 
# the model, where loss was lowest

callbacks = tf.keras.callbacks.EarlyStopping(monitor = 'loss', 
                                             patience = 10, 
                                             restore_best_weights = True)

# %%
#lets now train the model! We can store all teh model output in 'history'.
# note that we are using the training generator for training data, the val 
# generator for validation data, we set the model to train for some number of epochs, 
# we tell teh network how many steps there are to get through the entire data set
# and we also give the network our callback to use.

history = model.fit(train_generator,
                    validation_data = validation_generator,
                    epochs= 100,
                    workers = 8,
                    steps_per_epoch = total_train // batch_size,
                    validation_steps =  total_val // batch_size,
                    callbacks =[callbacks])
# Out:
# Epoch 1/100
# 9/9 [==============================] - 8s 86ms/step - loss: 1.1522 - val_loss: 1.0946
# Epoch 2/100
# 9/9 [==============================] - 0s 33ms/step - loss: 1.1107 - val_loss: 1.0637
# Epoch 3/100
# 9/9 [==============================] - 0s 31ms/step - loss: 1.0815 - val_loss: 1.0372
# Epoch 4/100
# 9/9 [==============================] - 0s 30ms/step - loss: 1.0552 - val_loss: 0.9876
# Epoch 5/100
# 9/9 [==============================] - 0s 31ms/step - loss: 1.0260 - val_loss: 0.9423
# Epoch 6/100
# 9/9 [==============================] - 0s 30ms/step - loss: 1.0124 - val_loss: 0.9659
# Epoch 7/100
# 9/9 [==============================] - 0s 31ms/step - loss: 1.0064 - val_loss: 0.9122
# Epoch 8/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.9980 - val_loss: 0.9564
# Epoch 9/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.9879 - val_loss: 0.9967
# Epoch 10/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.9748 - val_loss: 0.9200
# Epoch 11/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.9533 - val_loss: 0.9184
# Epoch 12/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.9284 - val_loss: 0.9748
# Epoch 13/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.8978 - val_loss: 0.8984
# Epoch 14/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.8635 - val_loss: 1.0167
# Epoch 15/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.8207 - val_loss: 1.0514
# Epoch 16/100
# 9/9 [==============================] - 1s 173ms/step - loss: 0.7886 - val_loss: 1.1923
# Epoch 17/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.7664 - val_loss: 1.1189
# Epoch 18/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.7584 - val_loss: 1.1610
# Epoch 19/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.7351 - val_loss: 1.1212
# Epoch 20/100
# 9/9 [==============================] - 0s 37ms/step - loss: 0.7343 - val_loss: 1.1997
# Epoch 21/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.7337 - val_loss: 1.4299
# Epoch 22/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.7175 - val_loss: 1.3062
# Epoch 23/100
# 9/9 [==============================] - 0s 40ms/step - loss: 0.7258 - val_loss: 1.4324
# Epoch 24/100
# 9/9 [==============================] - 0s 52ms/step - loss: 0.7110 - val_loss: 1.3130
# Epoch 25/100
# 9/9 [==============================] - 0s 55ms/step - loss: 0.7865 - val_loss: 1.4680
# Epoch 26/100
# 9/9 [==============================] - 0s 53ms/step - loss: 0.7247 - val_loss: 1.4852
# Epoch 27/100
# 9/9 [==============================] - 1s 62ms/step - loss: 0.8449 - val_loss: 1.4373
# Epoch 28/100
# 9/9 [==============================] - 0s 48ms/step - loss: 0.7178 - val_loss: 1.3611
# Epoch 29/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.7149 - val_loss: 1.4498
# Epoch 30/100
# 9/9 [==============================] - 0s 44ms/step - loss: 0.7234 - val_loss: 1.4609
# Epoch 31/100
# 9/9 [==============================] - 0s 38ms/step - loss: 0.7020 - val_loss: 1.2768
# Epoch 32/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.7376 - val_loss: 1.4431
# Epoch 33/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.6958 - val_loss: 1.5311
# Epoch 34/100
# 9/9 [==============================] - 0s 38ms/step - loss: 0.7575 - val_loss: 1.2309
# Epoch 35/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.6845 - val_loss: 1.3516
# Epoch 36/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.6876 - val_loss: 1.3305
# Epoch 37/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.6805 - val_loss: 1.3603
# Epoch 38/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.6766 - val_loss: 1.4274
# Epoch 39/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.6801 - val_loss: 1.4343
# Epoch 40/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.6755 - val_loss: 1.2541
# Epoch 41/100
# 9/9 [==============================] - 0s 39ms/step - loss: 0.6753 - val_loss: 1.3054
# Epoch 42/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.7087 - val_loss: 1.2093
# Epoch 43/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.6685 - val_loss: 1.4310
# Epoch 44/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.6664 - val_loss: 1.4328
# Epoch 45/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.6687 - val_loss: 1.7725
# Epoch 46/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.6618 - val_loss: 1.4665
# Epoch 47/100
# 9/9 [==============================] - 1s 113ms/step - loss: 0.6619 - val_loss: 1.3241
# Epoch 48/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.6570 - val_loss: 1.6796
# Epoch 49/100
# 9/9 [==============================] - 0s 39ms/step - loss: 0.6573 - val_loss: 1.1238
# Epoch 50/100
# 9/9 [==============================] - 0s 50ms/step - loss: 0.6627 - val_loss: 1.2975
# Epoch 51/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.6867 - val_loss: 1.7632
# Epoch 52/100
# 9/9 [==============================] - 0s 38ms/step - loss: 0.6528 - val_loss: 1.2227
# Epoch 53/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.6507 - val_loss: 1.6060
# Epoch 54/100
# 9/9 [==============================] - 0s 41ms/step - loss: 0.6480 - val_loss: 1.8232
# Epoch 55/100
# 9/9 [==============================] - 0s 56ms/step - loss: 0.6491 - val_loss: 1.4575
# Epoch 56/100
# 9/9 [==============================] - 0s 42ms/step - loss: 0.6825 - val_loss: 1.3728
# Epoch 57/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.7098 - val_loss: 1.8102
# Epoch 58/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.6450 - val_loss: 1.6293
# Epoch 59/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.6419 - val_loss: 1.0642
# Epoch 60/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.6413 - val_loss: 1.5895
# Epoch 61/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.6382 - val_loss: 1.7763
# Epoch 62/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.6349 - val_loss: 1.6366
# Epoch 63/100
# 9/9 [==============================] - 0s 48ms/step - loss: 0.6313 - val_loss: 1.7561
# Epoch 64/100
# 9/9 [==============================] - 1s 67ms/step - loss: 0.6268 - val_loss: 1.4696
# Epoch 65/100
# 9/9 [==============================] - 1s 64ms/step - loss: 0.7450 - val_loss: 1.6199
# Epoch 66/100
# 9/9 [==============================] - 1s 66ms/step - loss: 0.7208 - val_loss: 1.3397
# Epoch 67/100
# 9/9 [==============================] - 1s 60ms/step - loss: 0.7159 - val_loss: 1.5510
# Epoch 68/100
# 9/9 [==============================] - 0s 47ms/step - loss: 0.7809 - val_loss: 1.3638
# Epoch 69/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.7296 - val_loss: 1.7050
# Epoch 70/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.7192 - val_loss: 1.4601
# Epoch 71/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.6308 - val_loss: 1.1503
# Epoch 72/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.6283 - val_loss: 1.2939
# Epoch 73/100
# 9/9 [==============================] - 0s 41ms/step - loss: 0.6215 - val_loss: 1.5185
# Epoch 74/100
# 9/9 [==============================] - 0s 48ms/step - loss: 0.6206 - val_loss: 1.9771
# Epoch 75/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.6211 - val_loss: 1.4762
# Epoch 76/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.6185 - val_loss: 1.4045
# Epoch 77/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.7182 - val_loss: 1.2985
# Epoch 78/100
# 9/9 [==============================] - 0s 39ms/step - loss: 0.6128 - val_loss: 1.2799
# Epoch 79/100
# 9/9 [==============================] - 0s 39ms/step - loss: 0.6100 - val_loss: 1.0655
# Epoch 80/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.6033 - val_loss: 1.6343
# Epoch 81/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.6029 - val_loss: 1.7997
# Epoch 82/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.5964 - val_loss: 1.8005
# Epoch 83/100
# 9/9 [==============================] - 0s 37ms/step - loss: 0.5958 - val_loss: 1.4867
# Epoch 84/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.5926 - val_loss: 1.3037
# Epoch 85/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.5931 - val_loss: 1.2691
# Epoch 86/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.5870 - val_loss: 1.6911
# Epoch 87/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.5872 - val_loss: 1.7445
# Epoch 88/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.5792 - val_loss: 1.8514
# Epoch 89/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.5816 - val_loss: 1.3897
# Epoch 90/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.5842 - val_loss: 1.7774
# Epoch 91/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.5786 - val_loss: 1.6689
# Epoch 92/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.5690 - val_loss: 1.6125
# Epoch 93/100
# 9/9 [==============================] - 0s 38ms/step - loss: 0.5654 - val_loss: 1.5169
# Epoch 94/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.5664 - val_loss: 1.4838
# Epoch 95/100
# 9/9 [==============================] - 0s 38ms/step - loss: 0.5592 - val_loss: 1.6413
# Epoch 96/100
# 9/9 [==============================] - 0s 52ms/step - loss: 0.5595 - val_loss: 1.6102
# Epoch 97/100
# 9/9 [==============================] - 0s 44ms/step - loss: 0.6266 - val_loss: 1.6501
# Epoch 98/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.6155 - val_loss: 1.4393
# Epoch 99/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.5600 - val_loss: 1.5264
# Epoch 100/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.5475 - val_loss: 1.7664

# %%
import pandas as pd

pd.DataFrame(history.history).plot(figsize=(8,5))
#plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#lets look at the model prediction on a single image.

# here is the gdrive path to the image
imgp = 'data/segmentation/images/images/CAM_BF_01_20220518011222 copy_jmbolewitz.jpg'

#we pull the image and preprocess it — normalizing and making it a array/tensor
img = tf.keras.preprocessing.image.load_img(imgp,target_size = imsize)
img = tf.keras.preprocessing.image.img_to_array(img)
img = img/255
img = np.expand_dims(img,axis=0)

#We use the model to make a prediction on this image
pred = model.predict(img)

# we use argmax to get the labels for the image (recall the output of the 
# model is a tensor with shape of the image and then a depth equal to the 
# number of classes. this argmax and squeeze are here to collapse that).
lab = np.argmax(pred.squeeze(),-1)


#lets look at the model results and the image

imgUP = matplotlib.image.imread(imgp)

fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(img.squeeze())
labels = ax2.matshow(lab)
cax = fig.colorbar(labels, ax = ax2)
plt.show()

# water: 0; road:1; neither : 2

# %%
filepath = './models/Unet_water_resizelayers'
model.save(filepath)
# Out:
# INFO:tensorflow:Assets written to: ./models/Unet_water_resizelayers\assets
